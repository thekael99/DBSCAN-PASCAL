# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd

# %%
res = pd.read_csv("res.txt")
res[0:10]
# Out:
#          x       y  cluster
# 0  25.0514  5.7475       27
# 1  26.6614  7.3414        1
# 2  25.2653  6.2466        1
# 3  25.2285  4.7447        1
# 4  25.7529  5.1564        1
# 5  24.0785  5.6693        1
# 6  25.2722  6.8676        1
# 7  24.6535  6.2443        1
# 8  26.9834  6.6330        1
# 9  25.7437  6.3179        1

# %%
num_class=len(res["cluster"].unique())
num_class
# Out:
# 28

# %%
plt.figure(figsize=(12,12))

# %%
N = num_class
fig, ax = plt.subplots(1,1, figsize=(10,10))

x = res["x"]
y = res["y"]
tag = res["cluster"]    

cmap = plt.cm.jet
cmaplist = [cmap(i) for i in range(cmap.N)]
cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)

bounds = np.linspace(0,N,N+1)
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)

scat = ax.scatter(x,y,s=1,c=tag,cmap=cmap, norm=norm)
cb = plt.colorbar(scat, spacing='proportional',ticks=bounds)
cb.set_label('Custom cbar')
ax.set_title('Discrete color mappings')
plt.show()

# %%
f = open("c_20_id.dat", "r")
cluster_origin = f.readlines()
cluster_origin = np.array([int(x.rstrip()) for x in cluster_origin])

# %%
N = 31
fig, ax = plt.subplots(1,1, figsize=(10,10))

x = res["x"]
y = res["y"]
tag = cluster_origin   

cmap = plt.cm.jet
cmaplist = [cmap(i) for i in range(cmap.N)]
cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)

bounds = np.linspace(0,N,N+1)
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)

scat = ax.scatter(x,y,c=tag,cmap=cmap, norm=norm)
cb = plt.colorbar(scat, spacing='proportional',ticks=bounds)
cb.set_label('Custom cbar')
ax.set_title('Discrete color mappings')
plt.show()
